# %% [markdown]
# # Decorators Exploration Notebook
#
# This notebook allows you to experiment with decorators interactively.
#
# **Note**: This is optional. Use this if you prefer interactive exploration.

# %% [markdown]
# ## Basic Decorator

# %%
from functools import wraps

def my_decorator(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        print("Before function")
        result = func(*args, **kwargs)
        print("After function")
        return result
    return wrapper

@my_decorator
def say_hello(name):
    return f"Hello, {name}!"

# Test it
say_hello("Alice")

# %% [markdown]
# ## Timer Decorator

# %%
import time

def timer(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print(f"{func.__name__} took {end - start:.4f} seconds")
        return result
    return wrapper

@timer
def slow_calculation():
    time.sleep(1)
    return sum(range(1000000))

# Test it
result = slow_calculation()
print(f"Result: {result}")

# %% [markdown]
# ## Your Experiments
#
# Use the cells below to experiment with your own decorators:

# %%
# Your code here
